# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('opencv_logo.png')
kernel = np.ones((5,5),np.float32)/25
dst = cv2.filter2D(img,-1,kernel)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('opencv_logo.png')
blur5 = cv2.blur(img,(5,5))
gblur = cv2.GaussianBlur(img,(5,5),0)
median = cv2.medianBlur(img,5)
bilf = cv2.bilateralFilter(img,9,75,75)
plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(blur5),plt.title('Blurred')
plt.xticks([]), plt.yticks([])
#plt.subplot(121),plt.imshow(gblur),plt.title('GaussianBlurred')
#plt.xticks([]), plt.yticks([])
#plt.subplot(122),plt.imshow(median),plt.title('Median')
#plt.xticks([]), plt.yticks([])
#plt.subplot(121),plt.imshow(bilf),plt.title('bilateral')
#plt.xticks([]), plt.yticks([])
plt.show()
